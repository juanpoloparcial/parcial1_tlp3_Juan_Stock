# %% [markdown]
# # Examen Parcial n°1 2da Parte - TLP3 - Python para Ciencia de Datos.

# %% [markdown]
# **A partir del datasets brindado, realizar los siguientes procedimientos:**
#
# * Importar datasets con Pandas.
# * Explorar los datos con los metodos correspondientes.
# * Limpieza de los datos (Normalización de datos).
# * Obtener estadisticas.
# * Mostrar los datos procesados con graficos utilizando la libreria Matplotlib.
# * Exportar el contenido a un archivo sqlite utilizando PANDAS.
#
#
# **Importante: Se debe documentar cada procedimiento realizado, siguiendo la siguiente estructura:**
#
# 1. Celda de Markdown (Documentación)
# 2. Código (Sin comentarios, se debe documentar lo sufiente solo en la celda de markdown).
#
#
# ### Criterios de Evaluación:
#
# 1. No esta permitido el uso de IAs durante el examen. (Desactivar Copilot o cualquier herramienta de IA para autocompletar codigo.)
#
# 2. Se deben utilizar nombres de variables descriptivos y claros (Utilizar la nomeclatura correspondiente para los nombres de variables).
#
# 3. Comentarios claros y concisos que expliquen el propósito de cada sección del código en una celda de markdown antes del código.
#
# 4. Utilizar mensajes de commit descriptivos. (Puedes utilizar la extension CONVENTIONAL COMMIT de VS-CODE).
#
# 5. Entrega en tiempo y forma (Parciales entregados fuera de hora o con commits pasados el horario de entrega quedará invalidado.)
#
# 6. Todo el código desarrollado debe ser subido a un repositorio en GitHub (el nombre del repositorio de seguir la siguiente estructura:
# **parcial1_tlp3_nombre_apellido**).
#
# 7. Para resolver las actividades se debe insertar casillas de codigo entre cada actividad del cuaderno de Jupyter.
#
# 8. Deben trabajar con el datasets adjunto.
#
# 9. Una vez finalizado el examen, los resultados deben quedar guardados debajo de cada celda (NO EJECUTAR LA OPCIÓN "borrar todas las salidas").
#
# **Importante:** Una vez finalizado el examen, marcar como completado en el classroom.

# %% [markdown]
# ## Actividades:
# ### 1. Importación del Dataset con Pandas
#
# En esta sección, se debe utilizar la librería Pandas para cargar el archivo CSV que contiene los datos de VENTAS en un DataFrame.

# %%
import pandas as pd

df = pd.read_csv("ventas.csv")

df.head(10)
# Out:
#    ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0         1            Ana           García  01-05-2024
# 1         2         Carlos            López  2024-01-08
# 2         3          sofía         martínez  2024-01-12
# 3         4          pedro        rodríguez  2024-01-15
# 4         5          Laura          Sánchez  18-01-2024
# 5         6          Diego            Pérez  2024-01-22
# 6         7      Valentina           Flores  2024-01-25
# 7         8           Juan          Ramírez  2024-01-29
# 8         9        Martina             Díaz  2024-02-02
# 9        10      sebastián            gómez  2024-02-05
#
#                  Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                  Laptop         1          1200.50      1200.50
# 1       Mouse Inalámbrico         2            25.75        51.50
# 2        Teclado Mecánico         1            75.99        75.99
# 3     Monitor 24 pulgadas         1              NaN          NaN
# 4   Auriculares Bluetooth         1            99.95        99.95
# 5               Webcam HD         1            45.50        45.50
# 6  Impresora Multifunción         1           150.75       150.75
# 7       Parlantes Estéreo         2              NaN          NaN
# 8                 SSD 1TB         1           110.00       110.00
# 9        Memoria RAM 16GB         1            65.80        65.80
#
#               Metodo_Pago Region
# 0      Tarjeta de Crédito  Norte
# 1                Efectivo    Sur
# 2  Transferencia Bancaria   Este
# 3       Tarjeta de Débito  Oeste
# 4      Tarjeta de Crédito  Norte
# 5                Efectivo    Sur
# 6  Transferencia Bancaria   Este
# 7       Tarjeta de Débito  Oeste
# 8      Tarjeta de Crédito  Norte
# 9                Efectivo    Sur

# %% [markdown]
# ### 2. Exploración Inicial de los Datos
#
# A continuación, se deben emplear métodos de Pandas para obtener una visión general del dataset.
# - 2.1: Visualizar las primeras filas y ultimas.
# - 2.2: Obtener informacion del df con su metodo correspondiente.
# - 2.3: Hacer un conteo de valores nulos.

# %%
#2.1
print("Primeras Filas")
print(df.head())
print("\n Últimas Filas")
print(df.tail())
# Out:
# Primeras Filas
#    ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0         1            Ana           García  01-05-2024
# 1         2         Carlos            López  2024-01-08
# 2         3          sofía         martínez  2024-01-12
# 3         4          pedro        rodríguez  2024-01-15
# 4         5          Laura          Sánchez  18-01-2024
#
#                 Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                 Laptop         1          1200.50      1200.50
# 1      Mouse Inalámbrico         2            25.75        51.50
# 2       Teclado Mecánico         1            75.99        75.99
# 3    Monitor 24 pulgadas         1              NaN          NaN
# 4  Auriculares Bluetooth         1            99.95        99.95
#
#               Metodo_Pago Region
# 0      Tarjeta de Crédito  Norte
# 1                Efectivo    Sur
# 2  Transferencia Bancaria   Este
# 3       Tarjeta de Débito  Oeste
# 4      Tarjeta de Crédito  Norte
#
#  Últimas Filas
#      ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 100       101        Agustín           Torres  2024-10-08
# 101       102         Camila             Vega  2024-10-11
# 102       103           Juan            Rojas  2024-10-15
# 103       104          Lucía            Silva  2024-10-18
# 104       105          mateo             luna  2024-10-22
#
#                  Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 100        Pen Drive 64GB         4             8.75         35.0
# 101         Laptop Ligera         1              NaN       1180.0
# 102                   NaN         1            48.99          NaN
# 103     Teclado Bluetooth         1            78.20         78.2
# 104  Monitor para Oficina         1             2.00        210.5
#
#                 Metodo_Pago Region
# 100       Tarjeta de Débito  Oeste
# 101      Tarjeta de Crédito  Norte
# 102                Efectivo    Sur
# 103  Transferencia Bancaria   Este
# 104       Tarjeta de Débito  Oeste

# %%
#2.2
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Venta          105 non-null    int64
#  1   Nombre_Cliente    105 non-null    object
#  2   Apellido_Cliente  105 non-null    object
#  3   Fecha             105 non-null    object
#  4   Producto          101 non-null    object
#  5   Cantidad          105 non-null    int64
#  6   Precio_Unitario   92 non-null     float64
#  7   Total_Venta       92 non-null     float64
#  8   Metodo_Pago       94 non-null     object
#  9   Region            100 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 8.3+ KB
# None

# %%
#2.3
print(df.isnull().sum())
# Out:
# ID_Venta             0
# Nombre_Cliente       0
# Apellido_Cliente     0
# Fecha                0
# Producto             4
# Cantidad             0
# Precio_Unitario     13
# Total_Venta         13
# Metodo_Pago         11
# Region               5
# dtype: int64

# %% [markdown]
# ### 3. Limpieza y Normalización de los Datos
#
# - 3.1. Esta etapa crucial deben aplicar la corrección de diversos errores presentes en el dataset. Se abordarán los valores faltantes (Deben aplicar los metodos que ustedes crean convenientes **(Solo 1)**, por ejemplo: Eliminación de filas, cubrir valores con media, mediana, etc.)
# - 3.2: La columna Fecha deberan pasarla al tipo datetime con su metodo correspondiente.
# - 3.3: Corregir las mayusculas en el caso de Nombre y Apellido (Si es que corresponde.)

# %%
#3.1
df.dropna(subset=["Producto", "Precio_Unitario", "Total_Venta","Metodo_Pago","Region"], inplace=True)
print(df.head(10))
# Out:
#     ID_Venta Nombre_Cliente Apellido_Cliente      Fecha  \
# 0          1            Ana           García 2024-01-05
# 1          2         Carlos            López        NaT
# 2          3          Sofía         Martínez        NaT
# 4          5          Laura          Sánchez        NaT
# 5          6          Diego            Pérez        NaT
# 6          7      Valentina           Flores        NaT
# 8          9        Martina             Díaz        NaT
# 9         10      Sebastián            Gómez        NaT
# 10        11          Lucía             Ruiz        NaT
# 11        12          Mateo        Fernández        NaT
#
#                   Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                   Laptop         1          1200.50      1200.50
# 1        Mouse Inalámbrico         2            25.75        51.50
# 2         Teclado Mecánico         1            75.99        75.99
# 4    Auriculares Bluetooth         1            99.95        99.95
# 5                Webcam HD         1            45.50        45.50
# 6   Impresora Multifunción         1           150.75       150.75
# 8                  SSD 1TB         1           110.00       110.00
# 9         Memoria RAM 16GB         1            65.80        65.80
# 10                  Laptop         1          1150.00      1150.00
# 11       Mouse Inalámbrico         1            28.99        28.99
#
#                Metodo_Pago Region
# 0       Tarjeta de Crédito  Norte
# 1                 Efectivo    Sur
# 2   Transferencia Bancaria   Este
# 4       Tarjeta de Crédito  Norte
# 5                 Efectivo    Sur
# 6   Transferencia Bancaria   Este
# 8       Tarjeta de Crédito  Norte
# 9                 Efectivo    Sur
# 10  Transferencia Bancaria   Este
# 11       Tarjeta de Débito  Oeste

# %%
#3.2
serie = df["Fecha"]

serie = pd.Series(serie)
serie2 = pd.to_datetime(serie, format="%Y-%m-%d", errors="coerce")
serie1 = pd.to_datetime(serie, format="%d-%m-%Y", errors="coerce")
serie_final = serie1.combine_first(serie2)
print(serie_final)
print("Fechas ")
print(df.head(10))
# Out:
# 0     2024-01-05
# 1            NaT
# 2            NaT
# 4            NaT
# 5            NaT
#          ...
# 98           NaT
# 99           NaT
# 100          NaT
# 103          NaT
# 104          NaT
# Name: Fecha, Length: 68, dtype: datetime64[ns]
# Fechas
#     ID_Venta Nombre_Cliente Apellido_Cliente      Fecha  \
# 0          1            Ana           García 2024-01-05
# 1          2         Carlos            López        NaT
# 2          3          Sofía         Martínez        NaT
# 4          5          Laura          Sánchez        NaT
# 5          6          Diego            Pérez        NaT
# 6          7      Valentina           Flores        NaT
# 8          9        Martina             Díaz        NaT
# 9         10      Sebastián            Gómez        NaT
# 10        11          Lucía             Ruiz        NaT
# 11        12          Mateo        Fernández        NaT
#
#                   Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                   Laptop         1          1200.50      1200.50
# 1        Mouse Inalámbrico         2            25.75        51.50
# 2         Teclado Mecánico         1            75.99        75.99
# 4    Auriculares Bluetooth         1            99.95        99.95
# 5                Webcam HD         1            45.50        45.50
# 6   Impresora Multifunción         1           150.75       150.75
# 8                  SSD 1TB         1           110.00       110.00
# 9         Memoria RAM 16GB         1            65.80        65.80
# 10                  Laptop         1          1150.00      1150.00
# 11       Mouse Inalámbrico         1            28.99        28.99
#
#                Metodo_Pago Region
# 0       Tarjeta de Crédito  Norte
# 1                 Efectivo    Sur
# 2   Transferencia Bancaria   Este
# 4       Tarjeta de Crédito  Norte
# 5                 Efectivo    Sur
# 6   Transferencia Bancaria   Este
# 8       Tarjeta de Crédito  Norte
# 9                 Efectivo    Sur
# 10  Transferencia Bancaria   Este
# 11       Tarjeta de Débito  Oeste

# %%
#3.3
df["Nombre_Cliente"] = df["Nombre_Cliente"].str.title().str.strip()
df["Apellido_Cliente"] = df["Apellido_Cliente"].str.title().str.strip()
print(df.head(8))
# Out:
#    ID_Venta Nombre_Cliente Apellido_Cliente      Fecha  \
# 0         1            Ana           García 2024-01-05
# 1         2         Carlos            López        NaT
# 2         3          Sofía         Martínez        NaT
# 4         5          Laura          Sánchez        NaT
# 5         6          Diego            Pérez        NaT
# 6         7      Valentina           Flores        NaT
# 8         9        Martina             Díaz        NaT
# 9        10      Sebastián            Gómez        NaT
#
#                  Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                  Laptop         1          1200.50      1200.50
# 1       Mouse Inalámbrico         2            25.75        51.50
# 2        Teclado Mecánico         1            75.99        75.99
# 4   Auriculares Bluetooth         1            99.95        99.95
# 5               Webcam HD         1            45.50        45.50
# 6  Impresora Multifunción         1           150.75       150.75
# 8                 SSD 1TB         1           110.00       110.00
# 9        Memoria RAM 16GB         1            65.80        65.80
#
#               Metodo_Pago Region
# 0      Tarjeta de Crédito  Norte
# 1                Efectivo    Sur
# 2  Transferencia Bancaria   Este
# 4      Tarjeta de Crédito  Norte
# 5                Efectivo    Sur
# 6  Transferencia Bancaria   Este
# 8      Tarjeta de Crédito  Norte
# 9                Efectivo    Sur

# %% [markdown]
# ### 4. Obtención de Estadísticas Descriptivas
#
# Después de la limpieza, deben hacer lo siguiente:
#
# - 4.1: calcular nuevamente las estadísticas descriptivas para observar el impacto del proceso de limpieza en los datos numéricos.
# - 4.2: Calcular estadísticas específicas por grupo (Agrupar dos columnas).

# %%
#4.1
print(df.isnull().sum())
print(df.describe())
# Out:
# ID_Venta             0
# Nombre_Cliente       0
# Apellido_Cliente     0
# Fecha               67
# Producto             0
# Cantidad             0
# Precio_Unitario      0
# Total_Venta          0
# Metodo_Pago          0
# Region               0
# dtype: int64
#          ID_Venta                Fecha   Cantidad  Precio_Unitario  \
# count   68.000000                    1  68.000000        68.000000
# mean    53.882353  2024-01-05 00:00:00   1.205882       191.744706
# min      1.000000  2024-01-05 00:00:00   1.000000         2.000000
# 25%     21.750000  2024-01-05 00:00:00   1.000000        41.337500
# 50%     55.000000  2024-01-05 00:00:00   1.000000        82.875000
# 75%     83.250000  2024-01-05 00:00:00   1.000000       181.675000
# max    105.000000  2024-01-05 00:00:00   4.000000      1350.750000
# std     32.854055                  NaN   0.612283       290.542705
#
#        Total_Venta
# count    68.000000
# mean    197.824853
# min      19.990000
# 25%      52.437500
# 50%      89.370000
# 75%     185.200000
# max    1350.750000
# std     287.854376

# %%
#4.2 - Calcular estadísticas específicas por grupo (Agrupar dos columnas).

# %% [markdown]
# ### 5. Visualización de los Datos con Matplotlib
#
# En esta sección, deben utilizar la librería Matplotlib para crear **UNA** visualización que permitan comprender mejor los datos de ventas.El grafico es a elección, puede crear **UNO** de los siguientes: histogramas, diagramas de dispersión, gráficos de barras y graficos de torta.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))

df["Metodo_Pago"].value_counts().plot(kind='pie', autopct = "%1.1f%", colors = ["red","blue","yellow","pink"])

plt.title("Métodos de Pago. ")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(6,5))
# ----> 5 df["Metodo_Pago"].value_counts().plot(kind='pie', autopct = "%1.1f%", colors = ["red","blue","yellow","pink"])
#       7 plt.title("Métodos de Pago. ")
#       9 plt.show()
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:2107, in PiePlot._make_plot(self, fig)
#    2105 else:
#    2106     blabels = None
# -> 2107 results = ax.pie(y, labels=blabels, **kwds)
#    2109 if kwds.get("autopct", None) is not None:
#    2110     patches, texts, autotexts = results
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\IPF-2025\Desktop\parcial_tlp\env\Lib\site-packages\matplotlib\axes\_axes.py:3450, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3448 yt = y + pctdistance * radius * math.sin(thetam)
#    3449 if isinstance(autopct, str):
# -> 3450     s = autopct % (100. * frac)
#    3451 elif callable(autopct):
#    3452     s = autopct(100. * frac)
#
# ValueError: incomplete format

# %% [markdown]
# ### 6. Exportación a Archivo SQLite
#
# Finalmente, deben utilizar la funcionalidad de Pandas para guardar el DataFrame procesado en una base de datos SQLite. Deben hacer una conexión y hacer una consulta para ver si los datos fueron cargados correctamente.

# %%
df.to_csv("ventas.csv", index= False)

df.tail(8)
# Out:
#      ID_Venta Nombre_Cliente Apellido_Cliente Fecha  \
# 95         96         Olivia          Herrera   NaT
# 96         97        Lautaro          Jiménez   NaT
# 97         98      Valentina           Moreno   NaT
# 98         99         Máximo           Suárez   NaT
# 99        100          Sofía            Núñez   NaT
# 100       101        Agustín           Torres   NaT
# 103       104          Lucía            Silva   NaT
# 104       105          Mateo             Luna   NaT
#
#                                  Producto  Cantidad  Precio_Unitario  \
# 95   Auriculares con Cancelación de Ruido         1           180.50
# 96            Lector de Códigos de Barras         1           115.00
# 97                 Impresora de Etiquetas         1           135.80
# 98                         Mini Parlantes         2            15.00
# 99                         SSD SATA 250GB         1            55.00
# 100                        Pen Drive 64GB         4             8.75
# 103                     Teclado Bluetooth         1            78.20
# 104                  Monitor para Oficina         1             2.00
#
#      Total_Venta             Metodo_Pago Region
# 95         180.5  Transferencia Bancaria   Este
# 96         115.0       Tarjeta de Débito  Oeste
# 97         135.8      Tarjeta de Crédito  Norte
# 98          30.0                Efectivo    Sur
# 99          55.0  Transferencia Bancaria   Este
# 100         35.0       Tarjeta de Débito  Oeste
# 103         78.2  Transferencia Bancaria   Este
# 104        210.5       Tarjeta de Débito  Oeste
